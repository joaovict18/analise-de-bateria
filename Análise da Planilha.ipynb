# %%
import pandas as pd
from math 
planilha = pd.read_excel("Baterias de Voo_nova.xlsx")
display(planilha)
# Out:
#    Voo  Tempo de voo (s)  Distância percorrida (m)  Carga transportada (g)  \
# 0    1               120                       350                     500
# 1    2               135                       400                     600
# 2    3                95                       200                     450
# 3    4               150                       450                     700
# 4    5               110                       300                     550
# 5    6                85                       180                     400
# 6    7               140                       420                     650
# 7    8               130                       380                     550
# 8    9               100                       250                     500
# 9   10               160                       500                     800
#
#    Velocidade média (m/s)  Desvio da trajetória (º)    Status
# 0                     2.9                       2.0  Completo
# ...

# %%
mediaTempo = planilha["Tempo de voo (s)"].sum() / len(planilha["Tempo de voo (s)"])
print(f"Média de tempo de voo: {mediaTempo}s")

soma = 0
for tempo in planilha["Tempo de voo (s)"]:
    soma += (tempo - mediaTempo)**2

variacao = soma / len(planilha["Tempo de voo (s)"])
# Out:
# Média de tempo de voo: 122.5s
